# %% [markdown]
# <a href="https://colab.research.google.com/github/IrfanArsyananda/Analisis-Data-dengan-Python/blob/main/Data%20Visualization/Contoh%20Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Preparing Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Bar Chart

# %% [markdown]
# ## 1. Matplotlib

# %%
# Perbandingan Jumlah Populasi berdasarkan Kota
cities = ('Bogor', 'Bandung', 'Jakarta', 'Semarang', 'Yogyakarta',
          'Surakarta','Surabaya', 'Medan', 'Makassar')

populations = (45076704, 11626410, 212162757, 19109629, 50819826, 17579085,
               3481, 287750, 785409)

# plt.bar(x=cities, height=populations)
# plt.xticks(rotation=45)
plt.barh(y=cities, width=populations)
plt.show()

# %% [markdown]
# ## 2. Matplotlib + Pandas

# %%
df = pd.DataFrame({
    'Cities': cities,
    'Population': populations,
})

df.sort_values(by='Population', inplace=True)

plt.barh(y=df["Cities"], width=df["Population"])
plt.xlabel("Population (Millions)")
plt.title("Population of Cities in Indonesia")
plt.show()

# %% [markdown]
# ## 3. Seaborn

# %%
sns.barplot(y=df["Cities"], x=df["Population"], orient="h", color='blue')
plt.xlabel("Population (Millions)")
plt.title("Population of Cities in Indonesia")
plt.show()

# %% [markdown]
# # Pie Chart

# %% [markdown]
# ## 1. Matplotlib

# %%
# Perbandingan Persentase berdasarkan Rasa
# Mode Pie Chart
flavors = ('Chocolate', 'Vanilla', 'Macha', 'Others')
votes = (50, 20, 30, 10)
colors = ('#8B4513', '#FFF8DC', '#93C572', '#E67F0D')
explode = (0.1, 0, 0, 0)

plt.pie(
    x=votes,
    labels=flavors,
    autopct='%1.1f%%',
    colors=colors,
    explode=explode
)
plt.show()

# %%
# Mode Donut Pie Chart
plt.pie(
    x=votes,
    labels=flavors,
    colors=colors,
    wedgeprops = {'width': 0.6}
)
plt.show()

# %% [markdown]
# # Histogram

# %% [markdown]
# ## 1. Matplotlib + Numpy

# %%
# Nilai random
x = np.random.normal(15, 5, 250)

plt.hist(x=x, bins=15)
plt.show()

# %% [markdown]
# ## 2. Seaborn

# %%
sns.histplot(x=x, bins=15, kde=True)
plt.show()

# %% [markdown]
# # Box Plot

# %% [markdown]
# 1. Matplotlib + Numpy + Seaborn

# %%
# Nilai random
x = np.random.normal(15, 5, 250)
sns.boxplot(x)
plt.show()

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# ## 1. Matplotlib

# %%
# Plot variabel diameter dengan massa lemon
lemon_diameter = [6.44, 6.87, 7.7, 8.85, 8.15,
                  9.96, 7.21, 10.04, 10.2, 11.06]
lemon_weight = [112.05, 114.58, 116.71, 117.4, 128.93,
                132.93, 138.92, 145.98, 148.44, 152.81]

plt.scatter(x=lemon_diameter, y=lemon_weight)
plt.show()

# %% [markdown]
# ## 2. Matplotlib + Seaborn

# %%
sns.scatterplot(x=lemon_diameter, y=lemon_weight)
plt.show()

# %%
# Melihat hubungan atau korelasi menggunakan 'regplot'
sns.regplot(x=lemon_diameter, y=lemon_weight)
plt.show()

# %% [markdown]
# # Line Chart

# %% [markdown]
# ## 1. Matplotlib

# %%
# Plot variabel diameter dengan massa lemon
lemon_diameter = [6.44, 6.87, 7.7, 8.85, 8.15,
                  9.96, 7.21, 10.04, 10.2, 11.06]
lemon_weight = [112.05, 114.58, 116.71, 117.4, 128.93,
                132.93, 138.92, 145.98, 148.44, 152.81]

plt.plot(lemon_diameter, lemon_weight)
plt.show()

# %% [markdown]
# ## 2. Matplotlib + Pandas

# %%
# Plot harga saham Bank Central Asia dengan kode saham BBCA
url = 'https://query1.finance.yahoo.com/v7/finance/download/BBCA.JK?period1=1644796800&period2=1676332800&interval=1d&events=history&includeAdjustedClose=true'
df = pd.read_csv(url)
df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(12, 5))
plt.plot(df['Date'], df['Close'], color='red')
plt.xlabel('Date',size=15)
plt.ylabel('Price',size=15)
plt.show()

# %% [markdown]
# # Clustered Bar Chart

# %% [markdown]
# ## 1. Seaborn

# %%
# Distribusi berat badan setiap spesies penguin
penguins = sns.load_dataset("penguins")

sns.barplot(data=penguins, x="species", y="body_mass_g", hue="sex", errorbar=None)
plt.show()

# %% [markdown]
# # Modification Scatter Plot

# %%
# Distribusi berat badan setiap spesies penguin
penguins = sns.load_dataset("penguins")

sns.scatterplot(data=penguins, x="body_mass_g", y="flipper_length_mm", hue="species", style="species")
plt.show()
